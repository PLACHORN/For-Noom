# %% [markdown]
# # Welcome to Jupyter!

# %%
import sys
# !pip install bs4
# !pip install beautifulsoup4

# %%
import bs4
from bs4  import BeautifulSoup
import requests

# %%
r = requests.get('https://www.hipflat.co.th/market/condo-khlong-toei-glzfmu')
soup = bs4.BeautifulSoup(r.text, "html")

# %%
places = soup.find_all("a", class_="directories__lists-element-name")

# %%
a=[]
for i in range(0, len(places)):
    print(places[i].text)
# Out:
# 14 เพลส อพาร์ทเม้น
# 168 สุขุมวิท 36
# 38 แมนชั่น
# 42 แกรนด์ เรสสิเด้นซ์
# กรีน ทาวเวอร์
# กรีน วิลล์ เอ๊กคูลซีฟ เรสสิเด้นส์
# กรุงเทพธานี ทาวเวอร์
# กันตะ แมนชั่น
# การ์เด้นโกรฟ สวีท
# คราม สุขุมวิท 26
# คริสตัล การ์เด้น
# ควินทารา ทรีเฮาส์ สุขุมวิท 42
# ควีนส์ ปาร์ค วิว
# คอนโด วัน ทองหล่อ
# คอนโด วัน เอ็กซ์ สุขุมวิท 26
# คอนโด โอกะ เฮ้าส์ สุขุมวิท 36
# คอนโดเลต ดเวล สุขุมวิท 26
# คอลัมน์ บางกอก
# คอสโม่ วิลล่า
# คาซ่า 24
# คิวบ์ สวีทส์ สุขุมวิท 46
# จัสมิน แกรนด์ เรสซิเดนส์
# จี เอ็ม ไฮ้ท์
# จีเอ็ม ทาวเวอร์
# จีเอ็ม เซอร์วิส อพาร์ตเมนท์
# จีเอ็ม แมนชั่น
# ชามา สุขุมวิท
# ชามา เลควิว อโศก
# ชาร์มมิง เรสซิเดนท์ สุขุมวิท 22
# ซัมเมอร์เซ็ท เลค พอยท์ บางกอก
# ซานติ 24
# ซิตี้ สมาร์ท สุขุมวิท18
# ซิตี้เลค ทาวเวอร์ สุขุมวิท 16
# ซิวเวอร์ เฮอริเทจ
# ซีจี คาซา อพาร์ทเมนท์
# ซีนิธ เพลส สุขุมวิท 42
# ดิ เอสเทลล์ พร้อมพงษ์
# ดิ เอ็กเซล ไฮด์อะเวย์ สุขุมวิท 50
# ดิ เอ็มโพริโอ เพลส
# ดิ แอดเดรส สุขุมวิท 28
# ดิ แอดเดรส สุขุมวิท 42
# ดีราจ เรสซิเดนซ์
# ดีร่า แมนชั่น
# ดีอาล แมนชั่น
# ...

# %%
links1 = []
for i in places:
    print(i.get('href'))
    links1.append(i.get('href'))
# Out:
# /projects/14-place-apartment-dhnbcb
# /projects/168-sukhumvit-36-sxiyrw
# /projects/38-mansion-clvseb
# /projects/42-grand-residence-dvytte
# /projects/green-tower-lrufzb
# /projects/green-ville-exclusive-residence-guxhnw
# /projects/krungthep-thani-tower-gpetop
# /projects/kanta-mansion-ihwnde
# /projects/gardengrove-suites-zviyqk
# /projects/kraam-sukhumvit-26-jkusyd
# /projects/crystal-garden-gehuds
# /projects/quintara-treehaus-sukhumvit-42-pkcdvu
# /projects/queens-park-view-ktuyua
# /projects/condo-one-thonglor-nlrolg
# /projects/condo-one-x-sukhumvit-26-fgetks
# /projects/oka-haus-sukhumvit-36-wzlbyx
# /projects/condolette-dwell-sukhumvit-26-kvkslp
# /projects/column-bangkok-ugerap
# /projects/cosmo-villa-ipwwgn
# /projects/casa-24-vvkqfv
# /projects/qube-sukhumvit-soi-46-lhqfak
# /projects/jasmine-grande-residence-takdoq
# /projects/gm-height-qphexu
# /projects/gm-tower-uynzbt
# /projects/gm-serviced-apartment-aspqgs
# /projects/gm-mansion-jrdqcd
# ...

# %%
r2 = requests.get('https://www.hipflat.co.th'+str(links1[1]))
soup2 = bs4.BeautifulSoup(r2.text, "html")

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="th" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <!-- For iPad with high-resolution Retina display running iOS ≥ 7: -->
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <!-- For iPad with high-resolution Retina display running iOS ≤ 6: -->
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <!-- For iPhone with high-resolution Retina display running iOS ≥ 7: -->
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <!-- For iPhone with high-resolution Retina display running iOS ≤ 6: -->
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <!-- For the iPad mini and the first- and second-generation iPad on iOS ≥ 7: -->
# <link href="/apple-touch-icon.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# ...

# %%
data1 = soup2.find_all("div", class_="property-description__content")
#data1 = soup21.find_all("p")

# %%
data1[0].text
# Out:
# '\n\n\n168 Sukhumvit 36 (168 สุขุมวิท 36)168 Sukhumvit 36 (168 สุขุมวิท 36) เป็นคอนโดมิเนียม ตั้งอยู่บน 98-100 ซอย แสนสบาย แขวง พระโขนง เขต คลองเตย กรุงเทพมหานคร 10110  โครงสร้างของ 168 สุขุมวิท 36 แล้วเสร็จในปี 2019 คอนโดนี้ มีอาคารเดียว  จำนวน 8 ชั้น และ รวมทั้งหมด 105 ยูนิต\nยูนิตที่ว่าง\n168 Sukhumvit 36 (168 สุขุมวิท 36) สำหรับขาย: 13 units ว่างพร้อมขายจาก ฿3,900,000 ถึง ฿13,900,000168 Sukhumvit 36 (168 สุขุมวิท 36) สำหรับเช่า: 31 units ว่างพร้อมเช่าจาก ฿14,000 ถึง ฿20,000 ต่อเดือน\nสถิติทางการตลาด\nราคาขายเฉลี่ยที่ 168 สุขุมวิท 36 คือ ฿147,121 ต่อ ตรม. สูงขึ้น 11.2% ปัจจุบันราคาขายเฉลี่ยในคลองเตย (฿132,280 ต่อ ตรม.)  และ สูงขึ้น 44.1% ราคาเฉลี่ยในกรุงเทพฯ (฿102,103 ต่อ ตรม.) ราคาขายที่ 168 สุขุมวิท 36 ได้ลดลงในช่วงหนึ่งปีที่ผ่านมา ราคาเช่าที่ 168 สุขุมวิท 36 คือ30.4% สูงขึ้น โดยเฉลี่ยในคลองเตยและ 53.0% สูงขึ้น โดยเฉลี่ยในกรุงเทพฯ\nสิ่งอำนวยความสะดวก\nสิ่งอำนวยความสะดวกที่ 168 Sukhumvit 36 (168 สุขุมวิท 36) รวมทั้ง ลิฟท์  ที่จอดรถ  การรักษาความปลอดภัย 24 ชั่วโมง  กล้องวงจรปิด  ส
# ...
